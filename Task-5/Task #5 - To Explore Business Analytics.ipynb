# %% [markdown]
# # TSF - Task5 - To Explore Business Analytics

# %% [markdown]
# ### Perform ‘Exploratory Data Analysis’ on the provided dataset ‘SampleSuperstore’ You are the business owner of the retail firm and want to see how your company is performing. You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data? You can choose any of the tool of your choice (Python/R/Tableau/PowerBI/Excel)

# %% [markdown]
# ### Dataset: https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view

# %% [markdown]
# # Exploratory Data Analysis- SampleSuperstore Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('SampleSuperstore.csv')

# %%
data
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 8     Standard Class     Consumer  United States      Los Angeles
# 9     Standard Class     Consumer  United States      Los Angeles
# 10    Standard Class     Consumer  United States      Los Angeles
# 11    Standard Class     Consumer  United States      Los Angeles
# 12    Standard Class     Consumer  United States          Concord
# 13    Standard Class     Consumer  United States          Seattle
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 16    Standard Class     Consumer  United States          Madison
# 17      Second Class     Consumer  United States      West Jordan
# 18      Second Class     Consumer  United States    San Francisco
# 19      Second Class     Consumer  United States    San Francisco
# 20      Second Class     Consumer  United States    San Francisco
# 21    Standard Class    Corporate  United States          Fremont
# 22    Standard Class    Corporate  United States          Fremont
# 23      Second Class     Consumer  United States     Philadelphia
# 24    Standard Class     Consumer  United States             Orem
# 25      Second Class     Consumer  United States      Los Angeles
# 26      Second Class     Consumer  United States      Los Angeles
# 27    Standard Class     Consumer  United States     Philadelphia
# 28    Standard Class     Consumer  United States     Philadelphia
# 29    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9964    Second Class    Corporate  United States           Newark
# 9965    Second Class    Corporate  United States           Newark
# 9966    Second Class    Corporate  United States           Newark
# 9967  Standard Class     Consumer  United States       Plainfield
# 9968  Standard Class     Consumer  United States       Plainfield
# 9969  Standard Class     Consumer  United States       Plainfield
# 9970  Standard Class  Home Office  United States           Smyrna
# 9971  Standard Class  Home Office  United States           Smyrna
# 9972  Standard Class     Consumer  United States          Houston
# 9973  Standard Class  Home Office  United States      Los Angeles
# 9974  Standard Class  Home Office  United States      Los Angeles
# 9975  Standard Class  Home Office  United States      Los Angeles
# 9976  Standard Class  Home Office  United States      Los Angeles
# 9977  Standard Class  Home Office  United States      Los Angeles
# 9978  Standard Class  Home Office  United States      Los Angeles
# 9979  Standard Class  Home Office  United States      Los Angeles
# 9980    Second Class     Consumer  United States        Lafayette
# 9981     First Class     Consumer  United States        Fairfield
# 9991   258.5760         2      0.20    19.3932
# 9992    29.6000         4      0.00    13.3200
# 9993   243.1600         2      0.00    72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# # Dataset Statistics

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.count()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# # Checking for null values

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
#dropping the Country because all data is from US
data.drop('Country', axis =1, inplace = True)

# %%
#dropping the Postal Code because same as City
data.drop('Postal Code', axis = 1, inplace = True)
data
# Out:
#            Ship Mode      Segment             City           State   Region  \
# 0       Second Class     Consumer        Henderson        Kentucky    South
# 1       Second Class     Consumer        Henderson        Kentucky    South
# 2       Second Class    Corporate      Los Angeles      California     West
# 3     Standard Class     Consumer  Fort Lauderdale         Florida    South
# 4     Standard Class     Consumer  Fort Lauderdale         Florida    South
# 5     Standard Class     Consumer      Los Angeles      California     West
# 6     Standard Class     Consumer      Los Angeles      California     West
# 7     Standard Class     Consumer      Los Angeles      California     West
# 8     Standard Class     Consumer      Los Angeles      California     West
# 9     Standard Class     Consumer      Los Angeles      California     West
# 10    Standard Class     Consumer      Los Angeles      California     West
# 11    Standard Class     Consumer      Los Angeles      California     West
# 12    Standard Class     Consumer          Concord  North Carolina    South
# 13    Standard Class     Consumer          Seattle      Washington     West
# 14    Standard Class  Home Office       Fort Worth           Texas  Central
# 15    Standard Class  Home Office       Fort Worth           Texas  Central
# 16    Standard Class     Consumer          Madison       Wisconsin  Central
# 9990        Furniture  Furnishings    91.9600         2      0.00    15.6332
# 9991       Technology       Phones   258.5760         2      0.20    19.3932
# 9992  Office Supplies        Paper    29.6000         4      0.00    13.3200
# 9993  Office Supplies   Appliances   243.1600         2      0.00    72.9480
#
# [9994 rows x 11 columns]

# %%
data['City'].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
# Houston            377
# Chicago            314
# Columbus           222
# San Diego          170
# Springfield        163
# Dallas             157
# Jacksonville       125
# Detroit            115
# Newark              95
# Richmond            90
# Jackson             82
# Columbia            81
# Aurora              68
# Phoenix             63
# Long Beach          61
# Arlington           60
# San Antonio         59
# Louisville          57
# Miami               57
# Rochester           53
# Charlotte           52
# Henderson           51
# Lakewood            49
# Lancaster           46
# Fairfield           45
#                   ...
# Jefferson City       1
# Portage              1
# Pensacola            1
# Hagerstown           1
# Elyria               1
# Davis                1
# Waukesha             1
# Bartlett             1
# Rochester Hills      1
# Murrieta             1
# Melbourne            1
# Pico Rivera          1
# Deer Park            1
# Conway               1
# San Luis Obispo      1
# Redding              1
# Conroe               1
# Abilene              1
# Orland Park          1
# Kissimmee            1
# Margate              1
# Layton               1
# Baytown              1
# Vacaville            1
# Waterloo             1
# Saint Peters         1
# Romeoville           1
# Lindenhurst          1
# Springdale           1
# Chapel Hill          1
# Name: City, Length: 531, dtype: int64

# %%
#Total City 
data['City'].nunique()
# Out:
# 531

# %%
#total State
data['State'].nunique()
# Out:
# 49

# %%
#plotting the category
plt.figure(figsize = (10,6))
data['Category'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# From the above bar plot it is clear that office supplies have most sales

# %%
#Finding Which item is sale more in Sub_category
fig = plt.figure(figsize= (10,7))
data['Sub-Category'].value_counts().plot.pie(autopct = '%.2f',shadow = True)

# %% [markdown]
# Paper has the most sales in sub-category followed by Furnishings, Phones, Storage

# %%
# Region VS Category
pd.crosstab(data['Region'],data['Category']).plot(kind = 'bar',figsize=(10,6))

# %% [markdown]
# For all regions, Office Supplies have the maximum sales. West US has maximum sales while South US have minimum sales

# %%
#adding profit column WITH PERCENTAGE
data['%_profit'] = data['Profit'] / data['Sales'] * 100
data.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit  \
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164
#
#    %_profit
# 0     16.00
# 1     30.00
# 2     47.00
# 3    -40.00
# 4     11.25

# %%
print("MAXIMUM PROFIT")
max(data['%_profit'])
# Out:
# MAXIMUM PROFIT
# 50.0

# %%
print("MAXIMIM LOSS")
min(data['%_profit'])
# Out:
# MAXIMIM LOSS
# -275.0

# %%
#checking total data less than zero
loss = data[data['%_profit'] < 0]
loss
# Out:
#            Ship Mode      Segment              City         State   Region  \
# 3     Standard Class     Consumer   Fort Lauderdale       Florida    South
# 14    Standard Class  Home Office        Fort Worth         Texas  Central
# 15    Standard Class  Home Office        Fort Worth         Texas  Central
# 23      Second Class     Consumer      Philadelphia  Pennsylvania     East
# 27    Standard Class     Consumer      Philadelphia  Pennsylvania     East
# 28    Standard Class     Consumer      Philadelphia  Pennsylvania     East
# 32    Standard Class     Consumer      Philadelphia  Pennsylvania     East
# 36       First Class    Corporate        Richardson         Texas  Central
# 38    Standard Class  Home Office           Houston         Texas  Central
# 39    Standard Class  Home Office           Houston         Texas  Central
# 66    Standard Class  Home Office           Chicago      Illinois  Central
# 72    Standard Class     Consumer           Memphis     Tennessee    South
# 74    Standard Class     Consumer           Memphis     Tennessee    South
# 75       First Class    Corporate           Houston         Texas  Central
# 76       First Class    Corporate           Houston         Texas  Central
# 78      Second Class     Consumer           Houston         Texas  Central
# 84       First Class  Home Office           Chicago      Illinois  Central
# 95    Standard Class  Home Office          Portland        Oregon     West
# 100   Standard Class  Home Office           Chicago      Illinois  Central
# 101   Standard Class  Home Office           Chicago      Illinois  Central
# 103   Standard Class     Consumer            Aurora      Colorado     West
# 104   Standard Class     Consumer            Aurora      Colorado     West
# 105   Standard Class     Consumer            Aurora      Colorado     West
# 118   Standard Class    Corporate           Bristol     Tennessee    South
# 124     Second Class  Home Office           Houston         Texas  Central
# 125   Standard Class     Consumer       Bloomington      Illinois  Central
# 126   Standard Class     Consumer           Phoenix       Arizona     West
# 128     Second Class  Home Office       Los Angeles    California     West
# 130      First Class    Corporate          Columbus          Ohio     East
# 165   Standard Class     Consumer       San Antonio         Texas  Central
# ...              ...          ...               ...           ...      ...
# 9788  Standard Class     Consumer           Houston         Texas  Central
# 9790  Standard Class     Consumer           Houston         Texas  Central
# 9792    Second Class     Consumer           Houston         Texas  Central
# 9794    Second Class     Consumer           Houston         Texas  Central
# 9795  Standard Class    Corporate           Chicago      Illinois  Central
# 9797  Standard Class    Corporate            Toledo          Ohio     East
# 9800  Standard Class    Corporate            Toledo          Ohio     East
# 9806  Standard Class  Home Office   Fort Lauderdale       Florida    South
# 9808  Standard Class     Consumer           Chicago      Illinois  Central
# 9816  Standard Class    Corporate  Saint Petersburg       Florida    South
# 9821  Standard Class    Corporate  Saint Petersburg       Florida    South
# 9826  Standard Class     Consumer     San Francisco    California     West
# 9831    Second Class     Consumer          Beaumont         Texas  Central
# 9834     First Class     Consumer          La Porte         Texas  Central
# 9835     First Class     Consumer          La Porte         Texas  Central
# 9794  Office Supplies      Binders    18.2400         3      0.80   -31.0080
# 9795  Office Supplies      Binders     3.7980         3      0.80    -5.8869
# 9797       Technology       Phones   235.1880         2      0.40   -43.1178
# 9800       Technology       Phones   107.1180         3      0.40   -21.4236
# 9806  Office Supplies      Binders    28.7520         8      0.70   -21.0848
# 9808  Office Supplies      Binders     2.1120         2      0.80    -3.3792
# 9816  Office Supplies      Storage   516.9600         4      0.20    -6.4620
# 9821  Office Supplies      Binders    18.2640         2      0.70   -13.3936
# 9826        Furniture       Chairs   195.1360         4      0.20   -12.1960
# 9831        Furniture  Furnishings     8.6240         7      0.60    -2.5872
# 9834        Furniture  Furnishings    14.0000         4      0.60    -6.3000
# 9835  Office Supplies      Binders    16.3920         2      0.80   -26.2272
# 9844        Furniture  Furnishings    61.5440         7      0.60   -40.0036
# 9869  Office Supplies      Binders     3.1320         2      0.70    -2.6100
# 9870  Office Supplies      Binders    22.4280         3      0.70   -17.9424
# 9876  Office Supplies      Storage   848.5440         4      0.20   -21.2136
# 9877  Office Supplies      Binders     8.7000         5      0.70    -6.3800
# 9878       Technology       Phones   122.3820         3      0.40   -24.4764
# 9899        Furniture       Tables   330.5880         1      0.40  -143.2548
# 9903        Furniture  Furnishings    25.1280         3      0.60    -6.9102
# 9912        Furniture       Chairs   362.1360         3      0.20   -54.3204
# 9919        Furniture       Chairs   528.4300         5      0.30  -143.4310
# 9920  Office Supplies      Binders    22.3860         7      0.80   -35.8176
# 9921  Office Supplies      Binders     5.7420         3      0.70    -4.5936
# 9931        Furniture    Bookcases   683.3320         4      0.15   -40.1960
# 9937        Furniture       Tables    71.0880         2      0.20    -1.7772
# 9962        Furniture    Bookcases   383.4656         4      0.32   -67.6704
#
#         %_profit
# 3     -40.000000
# 14   -180.000000
# 15   -150.000000
# 23     -1.428571
# 27    -54.000000
# 28    -73.333333
# 32    -83.333333
# 36    -77.500000
# 38     -8.823529
# 39     -7.142857
# 66     -7.142857
# 72    -13.750000
# 74    -25.000000
# 75   -155.000000
# 76    -60.000000
# 78    -75.000000
# 84    -21.250000
# 95    -66.666667
# 100   -11.250000
# 101  -170.000000
# 103   -11.250000
# 104    -3.750000
# 105   -70.000000
# 118   -73.333333
# 124    -1.428571
# 125   -66.000000
# 126   -76.666667
# 128   -11.250000
# 130   -20.000000
# 165   -16.666667
# ...          ...
# 9788   -1.428571
# 9790  -31.428571
# 9792  -27.142857
# 9794 -170.000000
# 9795 -155.000000
# 9797  -18.333333
# 9800  -20.000000
# 9806  -73.333333
# 9808 -160.000000
# 9816   -1.250000
# 9821  -73.333333
# 9826   -6.250000
# 9831  -30.000000
# 9834  -45.000000
# 9835 -160.000000
# 9844  -65.000000
# 9869  -83.333333
# 9870  -80.000000
# 9876   -2.500000
# 9877  -73.333333
# 9878  -20.000000
# 9899  -43.333333
# 9903  -27.500000
# 9912  -15.000000
# 9919  -27.142857
# 9920 -160.000000
# 9921  -80.000000
# 9931   -5.882353
# 9937   -2.500000
# 9962  -17.647059
#
# [1871 rows x 12 columns]

# %%
print("Total size of Loss data ")
loss.shape
# Out:
# Total size of Loss data
# (1871, 12)

# %%
print("total size of data")
data.shape
# Out:
# total size of data
# (9994, 12)

# %%
#calculating loss in data
1871/9994 * 100
# Out:
# 18.721232739643785

# %% [markdown]
# Around 18% of data is loss

# %% [markdown]
# # City wise profit

# %%
# city wise profit
profit_city = data.groupby("City").sum()['Profit']
profit_city
# Out:
# City
# Aberdeen                6.6300
# Abilene                -3.7584
# Akron                -186.6356
# Albuquerque           634.0881
# Alexandria            318.6183
# Allen                 -39.8775
# Allentown            -226.4504
# Altoona                -1.1835
# Amarillo             -387.9683
# Anaheim              1234.0036
# Andover               124.1886
# Ann Arbor             228.9158
# Antioch                 9.3312
# Apopka                 54.3634
# Apple Valley          292.5890
# Appleton              554.7663
# Arlington            4169.6969
# Arlington Heights       1.2348
# Arvada                 59.8556
# Asheville              77.5074
# Athens                479.3221
# Atlanta              6993.6629
# Atlantic City          11.6800
# Auburn                734.9167
# Aurora              -2691.7386
# Austin                -20.3938
# Avondale               76.1690
# Bakersfield           187.9247
# Baltimore            1676.1980
# Bangor                422.2204
#                        ...
# Visalia                88.0478
# Waco                 -520.1034
# Warner Robins          53.6884
# Warwick              1063.7956
# Washington           1059.5893
# Waterbury             338.9355
# Waterloo               11.8248
# Watertown             907.0072
# Waukesha               14.1700
# Wausau                 90.4306
# Waynesboro            603.3858
# West Allis             28.3708
# West Jordan           102.6723
# West Palm Beach        31.6092
# Westfield             153.1758
# Westland              389.5995
# Westminster           763.6886
# Wheeling             -107.3962
# Whittier               44.4768
# Wichita               323.9266
# Wilmington           1947.7019
# Wilson                -14.3360
# Woodbury              196.0962
# Woodland               33.3848
# Woodstock              79.9929
# Woonsocket             78.6791
# Yonkers              2767.7557
# York                 -102.1692
# Yucaipa                13.2080
# Yuma                 -465.9909
# Name: Profit, Length: 531, dtype: float64

# %%
profit_city.sort_values(ascending = False).head()
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Name: Profit, dtype: float64

# %% [markdown]
# Cities which have the maximum profit

# %%
profit_city.sort_values(ascending = False).head()
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Name: Profit, dtype: float64

# %% [markdown]
# Cities which have the maximum loss

# %%
#plotting
fig,axes = plt.subplots(1,2, figsize = (15,5))
profit_city.sort_values(ascending = False).head().plot(kind ='bar', ax = axes[0])
axes[0].tick_params(labelrotation = 10)
axes[0].set_title("MAXIMUM PROFIT OF CITY")

profit_city.sort_values(ascending = True).head().plot(kind='bar',ax = axes[1])
plt.xticks(rotation = 15)
plt.title("MINIMUM PROFIT OF CITY ")

plt.show()

# %% [markdown]
# New York City has maximum profit and Philadelphia has maximum loss

# %% [markdown]
# # State wise profit

# %%
#STATE wise profit distributiom
state_profit = data.groupby('State').sum()['Profit']

# %%
plt.figure(figsize =(18,5))
sns.barplot(x = state_profit.index, y=state_profit.values)
plt.xticks(rotation =90)
plt.title("STATE WISE PROFIT")
# Out:
# Text(0.5, 1.0, 'STATE WISE PROFIT')

# %% [markdown]
# According to the barplot, California has the maximum profit while Virginia has the minimum profit

# %%
state_profit.sort_values(ascending = False).head(5)
# Out:
# State
# California    76381.3871
# New York      74038.5486
# Washington    33402.6517
# Michigan      24463.1876
# Virginia      18597.9504
# Name: Profit, dtype: float64

# %%
# converting the dataframe
df_state_profit = pd.DataFrame(state_profit)
type(df_state_profit)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Region wise profit

# %%
region_profit = pd.DataFrame(data.groupby('Region').sum()['Profit'])

# %%
plt.pie(region_profit, labels = region_profit.index, autopct= "%.2f", explode = (0.05,0.05,0.05,0.20),radius=1.5)

centre_circle = plt.Circle((0,0), 0.90, fc = 'white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# East Region has the most profit

# %% [markdown]
# # City wise sales

# %%
city_sale = pd.DataFrame(data.groupby('City').sum()['Sales'])
city_sale_sort = city_sale.sort_values(by= 'Sales',ascending = False).head(10)

# %%
plt.pie(city_sale_sort, labels = city_sale_sort.index, autopct= "%.2f",shadow = True, radius = 2)

centre_circle = plt.Circle((0,0), 0.70, fc = 'white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# From the pie chart, it is clear that New York City has maximum sales followed by Los Angeles while Springfield has the minimum sales.

# %% [markdown]
# # State wise sales

# %%
state_sale = pd.DataFrame(data.groupby('State').sum()['Sales'])
state_sale_sort =state_sale.sort_values(by= 'Sales',ascending = False).head(10)

# %%
plt.pie(state_sale_sort, labels = state_sale_sort.index, autopct= "%.2f",shadow = True, radius = 2)

centre_circle = plt.Circle((0,0), 0.70, fc = 'white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# From the State wise Sales, we got to see that California acquired the first position and Virginia is at the bottom of the list.

# %% [markdown]
# # Region wise sales

# %%
region_sale = pd.DataFrame(data.groupby('Region').sum()['Sales'])
region_sale_sort =region_sale.sort_values(by= 'Sales',ascending = False).head(10)

# %%
plt.pie(region_sale_sort, labels = region_sale_sort.index, autopct= "%.2f",shadow = True, radius = 2)
centre_circle = plt.Circle((0,0), 0.90, fc = 'white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# As per the Rregion Wise Sales, West region has maximum sales with 31.58 followed by East with 29.55, Central with 21.82 and South region has minimum sales with 17.05

# %%
data.duplicated().sum()
# Out:
# 50

# %% [markdown]
# # Dropping duplicates values

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data
# Out:
#            Ship Mode      Segment             City           State   Region  \
# 0       Second Class     Consumer        Henderson        Kentucky    South
# 1       Second Class     Consumer        Henderson        Kentucky    South
# 2       Second Class    Corporate      Los Angeles      California     West
# 3     Standard Class     Consumer  Fort Lauderdale         Florida    South
# 4     Standard Class     Consumer  Fort Lauderdale         Florida    South
# 5     Standard Class     Consumer      Los Angeles      California     West
# 6     Standard Class     Consumer      Los Angeles      California     West
# 7     Standard Class     Consumer      Los Angeles      California     West
# 8     Standard Class     Consumer      Los Angeles      California     West
# 9     Standard Class     Consumer      Los Angeles      California     West
# 10    Standard Class     Consumer      Los Angeles      California     West
# 11    Standard Class     Consumer      Los Angeles      California     West
# 12    Standard Class     Consumer          Concord  North Carolina    South
# 13    Standard Class     Consumer          Seattle      Washington     West
# 14    Standard Class  Home Office       Fort Worth           Texas  Central
# 15    Standard Class  Home Office       Fort Worth           Texas  Central
# 16    Standard Class     Consumer          Madison       Wisconsin  Central
# 17      Second Class     Consumer      West Jordan            Utah     West
# 18      Second Class     Consumer    San Francisco      California     West
# 19      Second Class     Consumer    San Francisco      California     West
# 20      Second Class     Consumer    San Francisco      California     West
# 21    Standard Class    Corporate          Fremont        Nebraska  Central
# 22    Standard Class    Corporate          Fremont        Nebraska  Central
# 23      Second Class     Consumer     Philadelphia    Pennsylvania     East
# 24    Standard Class     Consumer             Orem            Utah     West
# 25      Second Class     Consumer      Los Angeles      California     West
# 26      Second Class     Consumer      Los Angeles      California     West
# 27    Standard Class     Consumer     Philadelphia    Pennsylvania     East
# 28    Standard Class     Consumer     Philadelphia    Pennsylvania     East
# 29    Standard Class     Consumer     Philadelphia    Pennsylvania     East
# ...              ...          ...              ...             ...      ...
# 9963        Same Day     Consumer     Philadelphia    Pennsylvania     East
# 9964    Second Class    Corporate           Newark        Delaware     East
# 9965    Second Class    Corporate           Newark        Delaware     East
# 9966    Second Class    Corporate           Newark        Delaware     East
# 9967  Standard Class     Consumer       Plainfield      New Jersey     East
# 9968  Standard Class     Consumer       Plainfield      New Jersey     East
# 9969  Standard Class     Consumer       Plainfield      New Jersey     East
# 9970  Standard Class  Home Office           Smyrna         Georgia    South
# 9971  Standard Class  Home Office           Smyrna         Georgia    South
# 9972  Standard Class     Consumer          Houston           Texas  Central
# 9973  Standard Class  Home Office      Los Angeles      California     West
# 9974  Standard Class  Home Office      Los Angeles      California     West
# 9975  Standard Class  Home Office      Los Angeles      California     West
# 9976  Standard Class  Home Office      Los Angeles      California     West
# 9977  Standard Class  Home Office      Los Angeles      California     West
# 9978  Standard Class  Home Office      Los Angeles      California     West
# 9979  Standard Class  Home Office      Los Angeles      California     West
# 9980    Second Class     Consumer        Lafayette       Louisiana    South
# 9969  Office Supplies   Appliances    22.7500         7      0.00     6.5975
# 9970  Office Supplies      Binders   119.5600         2      0.00    54.9976
# 9971  Office Supplies          Art   140.7500         5      0.00    42.2250
# 9972  Office Supplies    Envelopes    99.5680         2      0.20    33.6042
# 9973       Technology       Phones   271.9600         5      0.20    27.1960
# 9974  Office Supplies          Art    18.6900         7      0.00     5.2332
# 9975  Office Supplies        Paper    13.3600         2      0.00     6.4128
# 9976       Technology       Phones   249.5840         2      0.20    31.1980
# 9977  Office Supplies    Fasteners    13.8600         7      0.00     0.0000
# 9978  Office Supplies      Binders    13.3760         4      0.20     4.6816
# 9979  Office Supplies      Binders   437.4720        14      0.20   153.1152
# 9980        Furniture       Tables    85.9800         1      0.00    22.3548
# 9981  Office Supplies       Labels    16.5200         5      0.20     5.3690
# 9982  Office Supplies        Paper    35.5600         7      0.00    16.7132
# 9983       Technology       Phones    97.9800         2      0.00    27.4344
# 9984  Office Supplies       Labels    31.5000        10      0.00    15.1200
# 9985  Office Supplies     Supplies    55.6000         4      0.00    16.1240
# 9987       Technology  Accessories    79.9900         1      0.00    28.7964
# 9988       Technology       Phones   206.1000         5      0.00    55.6470
# 9989        Furniture  Furnishings    25.2480         3      0.20     4.1028
# 9990        Furniture  Furnishings    91.9600         2      0.00    15.6332
# 9991       Technology       Phones   258.5760         2      0.20    19.3932
# 9992  Office Supplies        Paper    29.6000         4      0.00    13.3200
# 9993  Office Supplies   Appliances   243.1600         2      0.00    72.9480
#
#         %_profit
# 0      16.000000
# 1      30.000000
# 2      47.000000
# 3     -40.000000
# 4      11.250000
# 5      29.000000
# 6      27.000000
# 7      10.000000
# 8      31.250000
# 9      30.000000
# 10      5.000000
# 11      7.500000
# 12     35.000000
# 13     32.500000
# 14   -180.000000
# 15   -150.000000
# 16      2.000000
# 17     18.000000
# 18     29.000000
# 19      7.500000
# 20     32.500000
# 21     26.000000
# 22     26.000000
# 23     -1.428571
# 24     23.000000
# 25     36.250000
# 26     13.000000
# 27    -54.000000
# 28    -73.333333
# 29     12.500000
# ...          ...
# 9963   35.000000
# 9964   48.000000
# 9965   47.000000
# 9966   47.000000
# 9967   45.000000
# 9968   45.000000
# 9969   29.000000
# 9970   46.000000
# 9971   30.000000
# 9972   33.750000
# 9973   10.000000
# 9974   28.000000
# 9975   48.000000
# 9976   12.500000
# 9977    0.000000
# 9978   35.000000
# 9979   35.000000
# 9980   26.000000
# 9981   32.500000
# 9982   47.000000
# 9983   28.000000
# 9984   48.000000
# 9985   29.000000
# 9987   36.000000
# 9988   27.000000
# 9989   16.250000
# 9990   17.000000
# 9991    7.500000
# 9992   45.000000
# 9993   30.000000
#
# [9944 rows x 12 columns]

# %% [markdown]
# # Heatmap: To represent correlation between entities

# %%
corr=data.corr()
sns.heatmap(corr,annot=True)

# %%
s1=pd.Series(np.array(data['City']))
print(s1.describe())
# Out:
# count              9944
# unique              531
# top       New York City
# freq                906
# dtype: object

# %%
s2=pd.Series(np.array(data['Category']))
print(s2.describe())
# Out:
# count                9944
# unique                  3
# top       Office Supplies
# freq                 5986
# dtype: object

# %%
sns.countplot(data['Segment'])
plt.show()

# %% [markdown]
# # Histogram

# %%
data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
data1 = data[['City','Category', 'State','Sales','Profit']]
# pandas pivot with multiple variables
heatmap1_data = pd.pivot_table(data1,values='Sales', index=["City"], columns='Category')

# %% [markdown]
# # Heatmap of sales in every city by category

# %%
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap1_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of sales in every State by category

# %%
heatmap2_data = pd.pivot_table(data1,values='Sales', index=["State"], columns='Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap2_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of profits in every state by category¶

# %%
heatmap3_data = pd.pivot_table(data1,values='Profit', index=["State"], columns='Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap3_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of profit in every city by category

# %%
heatmap4_data = pd.pivot_table(data1,values='Profit', index=["City"], columns='Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap4_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of profit in every city by segment

# %%
heatmap5_data = pd.pivot_table(data,values='Profit', index=["City"], columns='Segment')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap5_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of profits in every state by segment

# %%
heatmap6_data = pd.pivot_table(data,values='Profit', index=["State"], columns='Segment')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap6_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of sales in every state by segment

# %%
heatmap7_data = pd.pivot_table(data,values='Sales', index=["State"], columns='Segment')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap7_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of sales in every city by segment

# %%
heatmap8_data = pd.pivot_table(data,values='Sales', index=["City"], columns='Segment')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap8_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of sales in every city by sub-category

# %%
heatmap9_data = pd.pivot_table(data,values='Sales', index=["City"], columns='Sub-Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap9_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of sales in every state by sub-category

# %%
heatmap10_data = pd.pivot_table(data,values='Sales', index=["State"], columns='Sub-Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap10_data, cmap="BuGn")

# %% [markdown]
# # Heatmap of profit in every state by sub-category

# %%
heatmap11_data = pd.pivot_table(data,values='Profit', index=["State"], columns='Sub-Category')
plt.figure(figsize=(8, 12))
sns.heatmap(heatmap11_data, cmap="BuGn")

# %% [markdown]
# # Profits and sales per sub-category

# %%
plt.figure(figsize=(11,7))
data.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.show()
